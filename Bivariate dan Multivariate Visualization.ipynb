# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Scatter Plot

# %%
lemon_diameter = [6.44, 6.87, 7.7, 8.85, 8.15, 
                  9.96, 7.21, 10.04, 10.2, 11.06]
lemon_weight = [112.05, 114.58, 116.71, 117.4, 128.93, 
                132.93, 138.92, 145.98, 148.44, 152.81]

# %% [markdown]
# menggunakan library matplotlib

# %%
plt.scatter(x=lemon_diameter, y=lemon_weight)
plt.show()

# %% [markdown]
#  menggunakan function scatterplot() yang disediakan oleh library seaborn

# %%
import seaborn as sns

# %%
sns.scatterplot(x=lemon_diameter, y=lemon_weight)
plt.show()

# %%
sns.regplot(x=lemon_diameter, y=lemon_weight)
plt.show()

# %% [markdown]
# # Line Chart

# %%
plt.plot(lemon_diameter, lemon_weight)
plt.show()

# %%
import pandas as pd

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.50-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.3.0 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.3.0-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (2024.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-cp39-cp39-win_amd64.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.8.tar.gz (948 kB)
#      ---------------------------------------- 0.0/948.2 kB ? eta -:--:--
#      ------------------------------- ------ 786.4/948.2 kB 6.7 MB/s eta 0:00:01
#      -------------------------------------- 948.2/948.2 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\applications\anaconda3\envs\main-ds\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.50-py2.py3-none-any.whl (102 kB)
# Downloading frozendict-2.4.6-cp39-cp39-win_amd64.whl (37 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-5.3.0-cp39-cp39-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 86.9 kB/s eta 0:00:38
#    ----- ---------------------------------- 0.5/3.8 MB 86.9 kB/s eta 0:00:38
#    ----- ---------------------------------- 0.5/3.8 MB 86.9 kB/s eta 0:00:38
#    ----- ---------------------------------- 0.5/3.8 MB 86.9 kB/s eta 0:00:38
#    -------- ------------------------------- 0.8/3.8 MB 136.4 kB/s eta 0:00:23
#    -------- ------------------------------- 0.8/3.8 MB 136.4 kB/s eta 0:00:23
#    ----------- ---------------------------- 1.0/3.8 MB 179.8 kB/s eta 0:00:16
#    ----------- ---------------------------- 1.0/3.8 MB 179.8 kB/s eta 0:00:16
#    ------------- -------------------------- 1.3/3.8 MB 215.8 kB/s eta 0:00:12
#    ------------- -------------------------- 1.3/3.8 MB 215.8 kB/s eta 0:00:12
#    ---------------- ----------------------- 1.6/3.8 MB 250.4 kB/s eta 0:00:09
#    ---------------- ----------------------- 1.6/3.8 MB 250.4 kB/s eta 0:00:09
#    ------------------- -------------------- 1.8/3.8 MB 282.7 kB/s eta 0:00:07
#    ---------------------- ----------------- 2.1/3.8 MB 315.7 kB/s eta 0:00:06
#    --------------------------- ------------ 2.6/3.8 MB 386.2 kB/s eta 0:00:04
#    --------------------------- ------------ 2.6/3.8 MB 386.2 kB/s eta 0:00:04
#    ------------------------------ --------- 2.9/3.8 MB 412.2 kB/s eta 0:00:03
#    --------------------------------- ------ 3.1/3.8 MB 432.2 kB/s eta 0:00:02
#    --------------------------------- ------ 3.1/3.8 MB 432.2 kB/s eta 0:00:02
#    ----------------------------------- ---- 3.4/3.8 MB 443.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 443.4 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 450.6 kB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 450.6 kB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 453.6 kB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.8-py3-none-any.whl size=139012 sha256=7e28b0c7747c804c47e3659510663c97982014354ddd71da8f44af8ec8e1fdf5
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\06\b3\7f\ed42a7c83ad89f578928833f5789212c694a015b8bd6a407a1
# Successfully built peewee
# Installing collected packages: peewee, multitasking, lxml, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.6 html5lib-1.1 lxml-5.3.0 multitasking-0.0.11 peewee-3.17.8 yfinance-0.2.50

# %%
import yfinance as yf

# Unduh data BBCA
df = yf.download('BBCA.JK', start='2022-02-14', end='2023-02-14', interval='1d')
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Adj Close   Close    High     Low    Open    Volume
# Ticker          BBCA.JK BBCA.JK BBCA.JK BBCA.JK BBCA.JK   BBCA.JK
# Date
# 2022-02-14  7169.285156  7700.0  7775.0  7700.0  7750.0  57710700
# 2022-02-15  7332.223145  7875.0  7875.0  7725.0  7750.0  55617000
# 2022-02-16  7425.331543  7975.0  7975.0  7825.0  7850.0  77055100
# 2022-02-17  7355.500488  7900.0  7925.0  7800.0  7850.0  48704600
# 2022-02-18  7378.777344  7925.0  7950.0  7850.0  7950.0  56813400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Date, )              247 non-null    datetime64[ns]
#  1   (Adj Close, BBCA.JK)  247 non-null    float64
#  2   (Close, BBCA.JK)      247 non-null    float64
#  3   (High, BBCA.JK)       247 non-null    float64
#  4   (Low, BBCA.JK)        247 non-null    float64
#  5   (Open, BBCA.JK)       247 non-null    float64
#  6   (Volume, BBCA.JK)     247 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.6 KB

# %%
# Memindahkan indeks ke kolom biasa
df = df.reset_index()

# %%
df
# Out:
# Price        Date    Adj Close   Close    High     Low    Open     Volume
# Ticker                 BBCA.JK BBCA.JK BBCA.JK BBCA.JK BBCA.JK    BBCA.JK
# 0      2022-02-14  7169.285156  7700.0  7775.0  7700.0  7750.0   57710700
# 1      2022-02-15  7332.223145  7875.0  7875.0  7725.0  7750.0   55617000
# 2      2022-02-16  7425.331543  7975.0  7975.0  7825.0  7850.0   77055100
# 3      2022-02-17  7355.500488  7900.0  7925.0  7800.0  7850.0   48704600
# 4      2022-02-18  7378.777344  7925.0  7950.0  7850.0  7950.0   56813400
# ..            ...          ...     ...     ...     ...     ...        ...
# 242    2023-02-07  8398.968750  8850.0  8850.0  8750.0  8775.0  116014700
# 243    2023-02-08  8375.243164  8825.0  8850.0  8800.0  8825.0   54495500
# 244    2023-02-09  8446.420898  8900.0  8900.0  8800.0  8825.0   72381700
# 245    2023-02-10  8375.243164  8825.0  8900.0  8700.0  8875.0   62060900
# 246    2023-02-13  8422.695312  8875.0  8900.0  8775.0  8875.0   63775000
#
# [247 rows x 7 columns]

# %%
df.head()
# Out:
# Price        Date    Adj Close   Close    High     Low    Open    Volume
# Ticker                 BBCA.JK BBCA.JK BBCA.JK BBCA.JK BBCA.JK   BBCA.JK
# 0      2022-02-14  7169.285156  7700.0  7775.0  7700.0  7750.0  57710700
# 1      2022-02-15  7332.223145  7875.0  7875.0  7725.0  7750.0  55617000
# 2      2022-02-16  7425.331543  7975.0  7975.0  7825.0  7850.0  77055100
# 3      2022-02-17  7355.500488  7900.0  7925.0  7800.0  7850.0  48704600
# 4      2022-02-18  7378.777344  7925.0  7950.0  7850.0  7950.0  56813400

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Close'], color='red')
plt.xlabel('Date',size=15)
plt.ylabel('Price',size=15)
plt.show()

# %% [markdown]
# # Clustered Bar Chart

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
penguins[penguins.bill_length_mm.isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
print("Jumlah duplikasi: ", penguins.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.barplot(data=penguins, x="species", y="body_mass_g", hue="sex", errorbar=None)
plt.show()

# %% [markdown]
# # Box Plot

# %% [markdown]
# memodifikasi bentuk visualisasi data dengan menambahkan komponen visual tambahan seperti color, shape, serta texture untuk mendeskripsikan lebih banyak variabel.

# %%
df_boxplot = df[["Open", "High", "Low", "Close", "Adj Close"]]

# %%
df_boxplot.head()
# Out:
# Price     Open    High     Low   Close    Adj Close
# Ticker BBCA.JK BBCA.JK BBCA.JK BBCA.JK      BBCA.JK
# 0       7750.0  7775.0  7700.0  7700.0  7169.285156
# 1       7750.0  7875.0  7725.0  7875.0  7332.223145
# 2       7850.0  7975.0  7825.0  7975.0  7425.331543
# 3       7850.0  7925.0  7800.0  7900.0  7355.500488
# 4       7950.0  7950.0  7850.0  7925.0  7378.777344

# %%
sns.boxplot(data=df_boxplot, palette="rocket")
plt.ylabel('Price', size=15)
plt.show()

# %% [markdown]
# kita juga bisa memodifikasi scatter plot menggunakan shape atau color yang berbeda guna menampilkan hubungan lebih dari dua variabel data. Seperti pada contoh berikut.

# %%
sns.scatterplot(data=penguins, x="body_mass_g", y="flipper_length_mm", hue="species", style="species")
plt.show()

# %% [markdown]
# # Explanatory Analysis

# %%
df.head()
# Out:
# Price        Date    Adj Close   Close    High     Low    Open    Volume
# Ticker                 BBCA.JK BBCA.JK BBCA.JK BBCA.JK BBCA.JK   BBCA.JK
# 0      2022-02-14  7169.285156  7700.0  7775.0  7700.0  7750.0  57710700
# 1      2022-02-15  7332.223145  7875.0  7875.0  7725.0  7750.0  55617000
# 2      2022-02-16  7425.331543  7975.0  7975.0  7825.0  7850.0  77055100
# 3      2022-02-17  7355.500488  7900.0  7925.0  7800.0  7850.0  48704600
# 4      2022-02-18  7378.777344  7925.0  7950.0  7850.0  7950.0  56813400

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Close'], label='Close', color='red')
plt.plot(df['Date'], df['Open'], label='Open', color='blue')
plt.xlabel('Date',size=15)
plt.ylabel('Price (IDR)',size=15)
plt.title('BBCA Stock Price', size=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Close'], label='Close', color='red')
plt.plot(df['Date'], df['Open'], label='Open', color='blue')
plt.title('BBCA Stock Price', size=20)
plt.legend()
plt.show()

# %% [markdown]
# kita bisa menggunakan warna yang kontras untuk mengarahkan perhatian audiens pada bagian yang ingin di-highlight. Berikut merupakan contoh kode untuk meng-highlight bagian penting dalam sebuah visualisasi data.

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
adelie_df = penguins[penguins.species == 'Adelie']
chinstrap_df = penguins[penguins.species == 'Chinstrap']
gentoo_df = penguins[penguins.species == 'Gentoo']

# %%
adelie_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Pada kode berikut kita ingin memfokuskan audiens pada data salah satu spesies penguin yaitu gentoo yang memiliki ukuran paling besar di antara ketiga spesies tersebut.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=adelie_df, x='body_mass_g', y='flipper_length_mm', facecolor='lightgrey', label='Adelie')
sns.scatterplot(data=chinstrap_df, x="body_mass_g", y="flipper_length_mm", facecolor="lightgrey", label="Chinstrap")
sns.scatterplot(data=gentoo_df, x="body_mass_g", y="flipper_length_mm", facecolor="blue", label="Gentoo")
plt.legend()
plt.show()
